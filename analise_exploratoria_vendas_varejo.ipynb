# %% [markdown]
# # Leitura DataSet

# %%
# bibliotecas da análise
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
# leitura de DataSet

data = pd.read_excel('/content/drive/MyDrive/Database/Databases/teste.infostore/DB.xlsx')
data.head()
# Out:
#    id_vendas      datas   une  id_filial  id_vendedor  id_cliente  id_produto  \
# 0   40290612 2021-03-01  INF           1            2       22396       37478
# 1   40293768 2021-03-16  INF           1           99      729928       28958
# 2   40295273 2021-03-25  INF           1           99      310618       35737
# 3   40296201 2021-03-31  INF           1            3      176674       35737
# 4   40296807 2021-03-15  INF           2         1187      679377       34625
#
#    id_grupo  serie    nota   valor tipo  quantidade  valbruto  desconto  \
# 0        49      1  193670  199.00    V           1    199.00       0.0
# 1         5    701   35362   83.65    V           1     89.95       6.3
# 2        47    701   35936   49.95    V           1     49.95       0.0
# 3        47    701   36220   47.45    V           1     49.95       2.5
# 4         5    602   59457   15.95    V           1     15.95       0.0
#
#    turno  pis  cofins   icms     cmv
# ...

# %%
data = data.drop(['id_vendas', 'id_cliente', 'id_produto', 'id_grupo', 'serie', 'nota', 'tipo'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datas        10000 non-null  datetime64[ns]
#  1   une          10000 non-null  object
#  2   id_filial    10000 non-null  int64
#  3   id_vendedor  10000 non-null  int64
#  4   valor        10000 non-null  float64
#  5   quantidade   10000 non-null  int64
#  6   valbruto     10000 non-null  float64
#  7   desconto     10000 non-null  float64
#  8   turno        10000 non-null  object
#  9   pis          10000 non-null  float64
#  10  cofins       10000 non-null  float64
#  11  icms         10000 non-null  float64
#  12  cmv          10000 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(2)
# memory usage: 1015.8+ KB

# %%
data.isnull().sum()
# Out:
# id_vendas      0
# datas          0
# une            0
# id_filial      0
# id_vendedor    0
# id_cliente     0
# id_produto     0
# id_grupo       0
# serie          0
# nota           0
# valor          0
# tipo           0
# quantidade     0
# valbruto       0
# desconto       0
# turno          0
# pis            0
# cofins         0
# icms           0
# cmv            0
# dtype: int64

# %%
data.isna().sum()
# Out:
# id_vendas      0
# datas          0
# une            0
# id_filial      0
# id_vendedor    0
# id_cliente     0
# id_produto     0
# id_grupo       0
# serie          0
# nota           0
# valor          0
# tipo           0
# quantidade     0
# valbruto       0
# desconto       0
# turno          0
# pis            0
# cofins         0
# icms           0
# cmv            0
# dtype: int64

# %%
len(data)
# Out:
# 10000

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#            id_vendas                datas    une     id_filial   id_vendedor  \
# count   1.000000e+04                10000  10000  10000.000000  10000.000000
# unique           NaN                  146      3           NaN           NaN
# top              NaN  2021-03-31 00:00:00   INF            NaN           NaN
# freq             NaN                  355   9370           NaN           NaN
# first            NaN  2021-02-01 00:00:00    NaN           NaN           NaN
# last             NaN  2021-12-31 00:00:00    NaN           NaN           NaN
# mean    4.129558e+07                  NaN    NaN      6.646800    792.211600
# ...

# %%
data.nunique()
# Out:
# id_vendas      10000
# datas            146
# une                3
# id_filial         32
# id_vendedor      204
# id_cliente      6250
# id_produto      2258
# id_grupo          83
# serie             79
# nota            7222
# valor           2784
# tipo               2
# quantidade        24
# valbruto         840
# desconto        1610
# turno              3
# pis              266
# cofins           269
# icms            1753
# cmv             5171
# dtype: int64

# %% [markdown]
# # Análise Exploratória

# %%
data.head(3)
# Out:
#        datas   une  id_filial  id_vendedor   valor  quantidade  valbruto  \
# 0 2021-03-01  INF           1            2  199.00           1    199.00
# 1 2021-03-16  INF           1           99   83.65           1     89.95
# 2 2021-03-25  INF           1           99   49.95           1     49.95
#
#    desconto  turno  pis  cofins   icms     cmv
# 0       0.0  MANHA  0.0     0.0   0.00  144.03
# 1       6.3  MANHA  0.0     0.0  15.06   45.19
# 2       0.0  TARDE  0.0     0.0   0.00   22.54

# %%
# ordenando por coluna de preferência

data = data.sort_values(by = 'valor', ascending=False).reset_index(drop=True)
data.head(3)
# Out:
#        datas   une  id_filial  id_vendedor    valor  quantidade  valbruto  \
# 0 2021-10-19  INF           1         1298  33000.0          20   41380.0
# 1 2021-10-19  INF           1         1348  33000.0          20   41380.0
# 2 2021-11-16  INF          63         1281  30500.0          10   34990.0
#
#    desconto  turno  pis  cofins  icms       cmv
# 0    8380.0  MANHA  0.0     0.0   0.0  27171.09
# 1    8380.0  MANHA  0.0     0.0   0.0  27171.09
# 2    4490.0  TARDE  0.0     0.0   0.0  28375.28

# %%
# filtro loja INF
inf = data[data['une'].str.contains('INF')]
# filtro loja MOT
mot = data[data['une'].str.contains('MOT')]
# filtro loja SSG
ssg = data[data['une'].str.contains('SSG')]

# %%
# total por unidade
total_inf = inf[['une', 'valor']].groupby(['une']).sum().reset_index()
total_ssg = ssg[['une', 'valor']].groupby(['une']).sum().reset_index()
total_mot = mot[['une', 'valor']].groupby(['une']).sum().reset_index()

display(total_inf)
display(total_ssg)
display(total_mot)
# Out:
#     une       valor
# 0  INF   4455326.85
#     une      valor
# 0  SSG   943541.72
#     une     valor
# 0  MOT   31843.81

# %%
datas = data[['datas', 'valor', 'une']]

# %%
vendas_por_dia = datas[['datas', 'valor']].groupby(['datas']).sum().reset_index()

# %%
# unindo DFs

total_por_une = pd.concat([total_mot, total_inf, total_ssg]).sort_values(by = 'valor' ,ascending=False)

# %%
'''

legenda:

SSG = SAMSUNG

INF = INFOMEGA

MOT = MOTOROLA


'''

sns.barplot(data = total_por_une, x='une', y='valor')

# %%
data['une'].value_counts(ascending=True).plot.barh(title='Quantidade')

# %%
data['turno'].value_counts(ascending=True).plot.barh(title='Quantidade')

# %%
total_por_une[['valor', 'une']].value_counts(ascending=False).plot.barh(title='Quantidade')

# %%
title = 'Quantidade de Vendas por Unidade'


plt.bar(x = UnidadePorTurno.index, height= data['quantidade'])
plt.show()

# %%
unidade = data['une'].value_counts()

# %%
sns.set(font_scale=1.5, rc={'figure.figsize': (20,20)})
eixo = data.hist(bins=20, color='purple')

# %%
import plotly.express as px

# %%
plt.plot(data.index, data['valor'])
plt.title('Valor Total')
plt.ylabel('teste')
plt.xlabel('teste 2')
plt.show();

# %% [markdown]
# **Total de vendas**

# %%
# total de vendas por dia
df_data_venda = pd.DataFrame(df_geral[['datas', 'valor']].groupby(['datas']).sum().reset_index())
df_data_venda
# Out:
#          datas     valor
# 0   2021-02-01    208.00
# 1   2021-02-02  59052.10
# 2   2021-02-03  35252.35
# 3   2021-02-04  22188.00
# 4   2021-02-05   7623.30
# ..         ...       ...
# 141 2021-12-27  32313.18
# 142 2021-12-28   7702.43
# 143 2021-12-29  13401.47
# 144 2021-12-30  16366.87
# 145 2021-12-31   3218.95
#
# [146 rows x 2 columns]

# %%
# grafico 
grafico_vendas_mensal = px.histogram(df_data_venda, x='datas', y='valor', title='Evolução de Vendas por Mês', width=1200, height=800)
grafico_vendas_mensal.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *-> Datas próximas ao 5º dia útil e quinzena de pagamento representam o alto índice de compras*
#
# *-> Ação: Reportar ao time de Marketing, Trade Marketing sobre essa importante relevância*
#
# *-> Ação: Verificar datas de compras com datas de aniversários de clientes, é sugestivo disparar sms com promoção para este tipo de cliente*

# %%
# quantidade de vendas por dia de cada mês

qtd_vendas_por_dia = pd.DataFrame(df_geral[['datas', 'quantidade']].groupby(['datas']).count().reset_index())
qtd_vendas_por_dia.head(50)
# Out:
#         datas  quantidade
# 0  2021-02-01           2
# 1  2021-02-02          50
# 2  2021-02-03          34
# 3  2021-02-04           8
# 4  2021-02-05          11
# 5  2021-02-06           9
# 6  2021-02-08          19
# 7  2021-02-22          14
# 8  2021-02-23           8
# 9  2021-02-24          66
# 10 2021-02-25         118
# 11 2021-02-26           1
# 12 2021-02-27          98
# 13 2021-03-01         244
# 14 2021-03-02         102
# 15 2021-03-03          15
# 16 2021-03-04         151
# 17 2021-03-05          70
# 18 2021-03-06         248
# 19 2021-03-08          81
# 20 2021-03-09         125
# 21 2021-03-10         133
# 22 2021-03-11          86
# 23 2021-03-12         152
# 24 2021-03-13         227
# 25 2021-03-15         148
# 26 2021-03-16         192
# 27 2021-03-17         213
# 28 2021-03-18         147
# 29 2021-03-19         160
# 30 2021-03-20         257
# 31 2021-03-22         166
# 32 2021-03-23         103
# 33 2021-03-24         125
# ...

# %% [markdown]
# **3ª questão**

# %%
df_geral.head(3)
# Out:
#    id_vendas      datas   une  id_filial  id_vendedor  id_cliente  id_produto  \
# 0   40290612 2021-03-01  INF           1            2       22396       37478
# 1   40293768 2021-03-16  INF           1           99      729928       28958
# 2   40295273 2021-03-25  INF           1           99      310618       35737
#
#    id_grupo  serie    nota   valor tipo  quantidade  valbruto  desconto  \
# 0        49      1  193670  199.00    V           1    199.00       0.0
# 1         5    701   35362   83.65    V           1     89.95       6.3
# 2        47    701   35936   49.95    V           1     49.95       0.0
#
#    turno  pis  cofins   icms     cmv
# 0  MANHA  0.0     0.0   0.00  144.03
# 1  MANHA  0.0     0.0  15.06   45.19
# 2  TARDE  0.0     0.0   0.00   22.54

# %%
# produtos mais vendidos e menos vendidos
df_total_produtos = df_geral[['id_produto', 'quantidade']].groupby(['id_produto']).count()

# Dez mais vendidos
display(df_total_produtos.sort_values('quantidade', ascending=False).head(10).reset_index())

# Dez menos vendidos

display(df_total_produtos.sort_values('quantidade', ascending=False).tail(10).reset_index())
# Out:
#    id_produto  quantidade
# 0        8628         128
# 1       34511          83
# 2       20194          82
# 3       37208          66
# 4        8627          62
# 5       39208          62
# 6          58          62
# 7        8750          60
# 8       31483          57
# 9       38396          53
#    id_produto  quantidade
# 0       39584           1
# 1       39585           1
# 2       39587           1
# 3       34606           1
# 4       39594           1
# 5       38104           1
# 6       39597           1
# 7       39598           1
# 8       38101           1
# 9       41379           1

# %% [markdown]
# **Análise por turno de time**

# %%
# turno que mais vendeu

display(pd.DataFrame(df_geral['turno'].value_counts()))
display(pd.DataFrame(df_geral['turno'].value_counts(normalize=True).map("{:.1%}".format)))
# Out:
#        turno
# TARDE   6118
# MANHA   3046
# NOITE    836
#        turno
# TARDE  61.2%
# MANHA  30.5%
# NOITE   8.4%

# %% [markdown]
# **Vendedores**

# %%
# filtro

vendedor_por_une = pd.DataFrame(df_geral[['id_vendedor', 'une', 'quantidade']].groupby(['id_vendedor', 'une']).count().reset_index())
vendedor_por_une.sort_values('quantidade', ascending=False)
inf = vendedor_por_une[vendedor_por_une['une'].str.contains('INF')]
ssg = vendedor_por_une[vendedor_por_une['une'].str.contains('SSG')]
mot = vendedor_por_une[vendedor_por_une['une'].str.contains('MOT')]

# %%
display(inf.sort_values('quantidade', ascending=False).head(10))
# Out:
#     id_vendedor   une  quantidade
# 55          938  INF          891
# 21          500  INF          702
# 87         1063  INF          668
# 23          511  INF          637
# 34          764  INF          603
# 1             3  INF          539
# 5            99  INF          421
# 44          825  INF          342
# 90         1088  INF          249
# 0             2  INF          243

# %%
display(ssg.sort_values('quantidade', ascending=False).head(10))
# Out:
#      id_vendedor   une  quantidade
# 47           873  SSG           29
# 133         1243  SSG           23
# 49           889  SSG           22
# 139         1271  SSG           21
# 9            143  SSG           21
# 126         1228  SSG           20
# 160         1313  SSG           19
# 84          1048  SSG           19
# 106         1182  SSG           18
# 76          1021  SSG           18

# %%
display(mot.sort_values('quantidade', ascending=False).head(10))
# Out:
#      id_vendedor   une  quantidade
# 170         1325  MOT            5
# 156         1302  MOT            3
# 159         1307  MOT            3
# 130         1240  MOT            2
# 144         1285  MOT            2
# 93          1096  MOT            1
# 131         1241  MOT            1
# 200         1370  MOT            1
# 201         1371  MOT            1

# %% [markdown]
# *-> Iniciar avaliação aos vendedores abaixo da média.*

# %%
df_vendedores = pd.DataFrame(df_geral['id_vendedor'].value_counts())
df_vendedores.sort_values('id_vendedor', ascending=False).tail(10)
# Out:
#       id_vendedor
# 1096            1
# 963             1
# 370             1
# 1241            1
# 1371            1
# 1362            1
# 948             1
# 1250            1
# 1322            1
# 1364            1

# %% [markdown]
# **Ação: Verificar destino se PF e PJ**

# %%
# top 10 clientes

clientes = pd.DataFrame(df_geral['id_cliente'].value_counts())
display(clientes.sort_values('id_cliente', ascending=False).head(10))
# Out:
#         id_cliente
# 4              277
# 266474          93
# 55240           85
# 1065            23
# 197421          22
# 1051            20
# 18489           18
# 1989            17
# 411890          16
# 726747          15

# %% [markdown]
# **Quantidade de produtos mais devolvidos + percentual**

# %%
'''
legenda

V = VENDIDO

D = DEVOLVIDO
'''
display(df_geral['tipo'].value_counts())
display(df_geral['tipo'].value_counts(normalize=True).map("{:.1%}".format))
# Out:
# V    9697
# D     303
# Name: tipo, dtype: int64
# V    97.0%
# D     3.0%
# Name: tipo, dtype: object

# %%
# filtro coluna tipo - somente produtos devolvidos

df_produtos_devolvidos = df_geral[df_geral['tipo'] == ('D')]
df_produtos_devolvidos.head(3)
# Out:
#      id_vendas      datas   une  id_filial  id_vendedor  id_cliente  \
# 75    40300114 2021-03-20  INF           3          500      266474
# 96    40300638 2021-03-24  INF           3          938      266474
# 130   40298911 2021-03-11  INF           3         1063       55240
#
#      id_produto  id_grupo  serie   nota  valor tipo  quantidade  valbruto  \
# 75        38119        81      4  59355 -399.0    D          -1   -399.00
# 96        38452         4      4  59376 -179.9    D          -1   -179.90
# 130       28911        49      4  59252  -18.0    D          -1    -18.95
#
#      desconto  turno  pis  cofins   icms     cmv
# 75       0.00  TARDE  0.0     0.0 -27.93 -178.83
# 96       0.00  MANHA  0.0     0.0 -32.38  -85.22
# 130     -0.95  MANHA  0.0     0.0   0.00   -8.26

# %%
# produto mais devolvido

prod_mais_devolvido = df_produtos_devolvidos[['id_produto', 'quantidade']].groupby(['id_produto']).sum().reset_index()
display(prod_mais_devolvido.sort_values('quantidade', ascending=True).head(10))
# Out:
#      id_produto  quantidade
# 4          1027         -13
# 101       37192         -10
# 102       37208          -9
# 12         6068          -8
# 130       37831          -8
# 61        34511          -8
# 63        34514          -7
# 103       37209          -7
# 42        32220          -5
# 62        34513          -5

# %%
# valor de produto devolvido

vlr_total_devolvidos = df_produtos_devolvidos[['id_produto', 'valor']].groupby(['id_produto']).sum().reset_index()
display(vlr_total_devolvidos.sort_values('valor', ascending=True))
# Out:
#      id_produto    valor
# 191       39385 -8390.00
# 151       38514 -6599.00
# 152       38515 -6100.00
# 154       38537 -5100.00
# 194       39408 -4699.00
# ..          ...      ...
# 38        31484    -9.95
# 12         6068    -7.92
# 76        35983    -1.00
# 227       40944    -0.10
# 221       40547    -0.01
#
# [237 rows x 2 columns]

# %% [markdown]
# **Margem bruta**

# %%
df_geral.head(2)
# Out:
#    id_vendas      datas   une  id_filial  id_vendedor  id_cliente  id_produto  \
# 0   40290612 2021-03-01  INF           1            2       22396       37478
# 1   40293768 2021-03-16  INF           1           99      729928       28958
#
#    id_grupo  serie    nota   valor tipo  quantidade  valbruto  desconto  \
# 0        49      1  193670  199.00    V           1    199.00       0.0
# 1         5    701   35362   83.65    V           1     89.95       6.3
#
#    turno  pis  cofins   icms     cmv
# 0  MANHA  0.0     0.0   0.00  144.03
# 1  MANHA  0.0     0.0  15.06   45.19

# %%
margem_bruta = pd.DataFrame(df_geral[['une', 'valor', 'valbruto']].groupby(['une']).sum().reset_index())
valbruto = margem_bruta['valbruto']
valor_cliente_final = margem_bruta['valor']
# nova coluna
margem_bruta['margem_bruta'] = (valbruto - valor_cliente_final)
display(margem_bruta)
# Out:
#     une       valor    valbruto  margem_bruta
# 0  INF   4455326.85  4774415.50     319088.65
# 1  MOT     31843.81    34081.01       2237.20
# 2  SSG    943541.72  1279945.00     336403.28

# %%
margem_bruta_prod = pd.DataFrame(df_geral[['id_produto', 'valor', 'valbruto']].groupby(['id_produto']).sum().reset_index())
valbruto2 = margem_bruta_prod['valbruto']
valor_cliente_final2 = margem_bruta_prod['valor']
# nova coluna
margem_bruta_prod['margem_bruta_prod'] = (valbruto2 - valor_cliente_final2)
display(margem_bruta_prod)
# Out:
#       id_produto    valor  valbruto  margem_bruta_prod
# 0              9   325.30    339.80              14.50
# 1             19  2749.12   2837.55              88.43
# 2             23    47.45     49.95               2.50
# 3             43   469.30    489.65              20.35
# 4             56   527.70    549.35              21.65
# ...          ...      ...       ...                ...
# 2253       41317   179.85    179.85               0.00
# 2254       41328   229.95    229.95               0.00
# 2255       41330   119.95    119.95               0.00
# 2256       41353  3329.10   3699.00             369.90
# 2257       41379  1850.00   2299.00             449.00
#
# [2258 rows x 4 columns]
